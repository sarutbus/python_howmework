# %% [markdown]
# <a href="https://colab.research.google.com/github/sarutbus/python_howmework/blob/main/HW04_Web_Scarping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#HW04 - Create Luanched Year column in a dataFrame

# %%
# !pip install gazpacho
#import function

import pandas as pd
import gazpacho
import requests

#Web scarping

url = "https://www.imdb.com/search/title/?groups=top_100&sort=user_rating,desc"
headers = {"Accept-Language": "en-US"}
html = requests.get(url,headers = headers)
imdb = gazpacho.Soup(html.text)

# %%
#prepare data for dataframe

titles = imdb.find("h3", {"class": "lister-item-header"})
clean_title = [
    title.strip()[3:-7] for title in titles]

# %%
import re
metascores = imdb.find("div", {"class": "inline-block ratings-metascore"})
clean_metascore = [
    int(re.sub(r'\D', '',metascore.strip())) for metascore in metascores
    ]

# %%
ratings = imdb.find("div", {"class": "ratings-imdb-rating"})
clean_rating = [
    float(rating.strip()) for rating in ratings
    ]

# %%
import re

years = imdb.find("span", {"class": "lister-item-year"})

clean_year = [
    int(re.sub(r'\D', '',year.strip())) for year in years
    ]

# %%
movie = pd.DataFrame(data = {
    "title": clean_title,
    "rating": clean_rating,
    "metascore": clean_metascore,
    "year": clean_year
})

# %%
movie
# Out:
#                                                 title  rating  metascore  year
# 0                            The Shawshank Redemption     9.3         82  1994
# 1                                       The Godfather     9.2        100  1972
# 2                                     The Dark Knight     9.0         84  2008
# 3                                    Schindler's List     9.0         95  1993
# 4       The Lord of the Rings: The Return of the King     9.0         94  2003
# 5                                        12 Angry Men     9.0         97  1957
# 6                               The Godfather Part II     9.0         90  1974
# 7                                        Pulp Fiction     8.9         95  1994
# 8                                          Fight Club     8.8         67  1999
# 9    The Lord of the Rings: The Fellowship of the ...     8.8         92  2001
# 10                                          Inception     8.8         74  2010
# ...
